# %% [markdown]
# # Final Practice Problems

# %% [markdown]
# ## In an AVL tree, what is the valid range for the balance factor of any node?
#
# {-1,0,1}

# %% [markdown]
# ## According to the lecture materials, which single rotation is used to balance an AVL tree after an insertion into the left subtree of the left child causes an imbalance?
#
# LL Single rotation

# %% [markdown]
# ## A hash table of size 10 uses linear probing with the hash function h(x)=x mod 10. The keys 89, 18, 49, 58, and 9 are inserted in that exact order. What is the final index of the key 9?
#
# 49,58,9,x,x,x,x,x,18,89
#
# At index 2

# %% [markdown]
# ## Using double hashing with a table size of 10, $h_1(x) = x \text{ mod } 10$, and $h_2(x) = 7 - (x \text{ mod } 7)$. If the keys 89, 18, 49, 58, and 69 are inserted sequentially, what index is the key 69 placed at?

# %% [markdown]
# 0,x,x,58,x,x,49,x,18,89

# %% [markdown]
# Node what(Node first)
# 11 -> 22 -> 33 -> 44 -> null
#
# if
#     first or first.next is null and returns first
# else
#     Node rest = what(first.next)
#
# first.next.next = first;
# first.next = null;
#
# returns rest;

# %% [markdown]
# int func(int n) {
#     if (n <= 1) return 1;
#     else return n + func(n - 1);
#     }.
#
# What is the return value of func(5)
#
# func(5)
#     5 + func(5-1) = 15
# func (4)
#     4 + func(3) = 10
# func (3)
#     3 + func (2) = 6
# func (2)
#     2 + func(1) = 3
# Func(1)
#     1
#
#
# It is 15

# %% [markdown]
# Assume a Java LinkedList<String> list is initially empty.
# The following operations are executed: list.add("X"); list.add("Y"); list.addFirst("Z"); list.remove(1);.
# What does the list contain after these operations?
#
# Z Y

# %% [markdown]
# Question 2: Traversal Mechanics (True/False)
# True or False: When performing a Breadth-First Search (BFS) starting from vertex A, if A has unvisited adjacent neighbors B, C, and D, you will visit and enqueue all three of these neighbors before moving on to process the neighbors of vertex B.
#
# A B C D
#
# True

# %% [markdown]
# Imagine a graph with the following Adjacency List representation. Assume that when iterating through neighbors, we always visit them in alphabetical order.
#
# A: [B, C]
#
# B: [A, D, E]
#
# C: [A, F, G]
#
# D: [B]
#
# E: [B, H]
#
# F: [C]
#
# G: [C]
#
# H: [E]
#
# Problem 1: Depth-First Search (DFS) Tracing
# If you perform a Depth-First Search starting from vertex A, what is the exact order in which the vertices are visited? (Assume a standard recursive DFS, or a stack-based DFS where neighbors are pushed in reverse alphabetical order so the alphabetically first neighbor is popped first).
#
# []
# [A,B,D,E,H,C,F,G]
#
# Problem 2: Breadth-First Search (BFS) Tracing
# If you perform a Breadth-First Search starting from vertex A, what is the exact order in which the vertices are visited? (Assume a standard queue-based BFS).
#
# []
# [A,B,C,D,E,F,G,H]
