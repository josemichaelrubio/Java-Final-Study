# %% [markdown]
# # AVL
#
# ---

# %% [markdown]
# ## How to Calculate the Balance Factor
#
# the standard formula is:
# - `Balance Factor = Height(Left Subtree) - Height(Right Subtree)`
#     - **Height**: The number of *edges* on the longest downward path from the node to a leaf. (A leaf node itself has a height of 0, and an empty/null child has a height of -1).
#     - **Balanced**: An AVL tree is considered balanced if every node has a balance factor of -1, 0, or +1.
#
# ---

# %% [markdown]
# ## How to Perform an LL Rotation
#
# To fix an `LL` imbalance, we perform a `single Right Rotation` on the unbalanced node.
# - The middle node is pulled up to become the new root.
# - The unbalanced node is pushed down and to the right, becoming the right child of the new root.
# - The bottom node remains attached as the left child, which is the new root.
#
# ---

# %% [markdown]
# ### How to Perform an RR Rotation
#
# To fix an `RR` imbalance, we perform a single `Left Rotation` on the unbalanced node.
#
# - The middle node is pulled up to become the new root.
# - The unbalanced node is pushed down and to the left, becoming the left child, aka new root.
# - The bottom node remains attached as the right child, aka new root.
#
# ---

# %% [markdown]
# ## Practice Problems

# %% [markdown]
# ### Exercise 1: Compute Balance Factors in an AVL Tree
#
# Consider the AVL tree structure given below:
#
#             10
#           /    \
#          6      14
#         / \    /  \
#        2   8  12  16
#       / \
#      1   4
#
# Compute and write the balance factor for each node in the tree. Also, identify which nodes are unbalanced, if any.
#
# #### Answer:
#
#             10(1)
#           /       \
#        6(1)       14(0)
#        /  \       /    \
#       2(0) 8(0)  12(0)  16(0)
#       /  \
#      1(0) 4(0)
#
# It is the balanced

# %% [markdown]
# ### Exercise 2a: Perform LL Rotation in an AVL Tree
#
# Perform the required rotation(s) to balance the following AVL trees:
#
# (a) LL Rotation:
#
# Insert nodes with values: 10, 6, 2
# Draw the tree after each insertion.
# Then, perform a Left-Left (LL) rotation to balance the tree.
# Draw the final balanced tree.
#
# --
#
# #### Answer
#
# Insert 10, 6, 2:
#
#             10 (2)
#         6 (1)
#     2 (0)
# It became unbalanced
#
# LL Rotation:
#
#             6 (0)
#         2 (0)      10(0)
#
# Now it is balanced

# %% [markdown]
# ### Exercise 2b: Perform RR Rotation in an AVL Tree
#
# (b) RR Rotation:
#
# Insert nodes with values: 10, 14, 16
# Draw the tree after each insertion.
# Then, perform a Right-Right (RR) rotation to balance the tree.
# Draw the final balanced tree.
#
# #### Answer
#
# Insert nodes with values: 10, 14, 16:
#
#         10 (-2)
#             14 (-1)
#                 16(0)
#
# It is unbalanced:
#
# Perform a Right-Right (RR) rotation to balance the tree
#
#         14 (0)
#     10 (0)  16(0)
#
# It is balanced

# %% [markdown]
# ### Excerise 1: Calculate Balance Factor
# Calculate balance factor for nodes of the AVL tree.
#
#                    32
#                 /     \
#             16        48
#            / \        /  \
#            8  24     40       56
#                 \   /  \     /  \
#                  28 36 44  52   60
#                                 / \
#                                58  62
# --
# #### Answer
#                                 32 (-1)
#                              /       \
#                            /           \
#                        16 (-1)           48 (-1)
#                       /     \         /     \
#                     8 (0)   24 ()   40 (0)     56 (-1)
#                               \    /   \     /   \
#                             28(0) 36(0)44(0)52(0) 60 (0)
#                                                     /  \
#                                                   58 (0) 62 (0)

# %% [markdown]
# ### AVL Tree Insertion with Single Rotations
#
# Objective: Insert a different set of keys into an initially empty AVL tree, ensuring balance through only single rotations.
#
# Keys to Insert: 50, 60, 70, 40, 30
# --
#
#     50
#         60
#             70
# Unbalanced, does RR
#
#             60
#         50      70
#     40
# 30
# Unbalanced, so we do LL
#
#             60
#     40              70
# 30      50
#
# Done
